# %% [markdown]
# API_KEY
#
# 3IY8CKY4F8FZ3ON5PFY2

# %% [markdown]
# 수출금액지수

# %%
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "403Y001"
start = "1"
end = "100000"
period = "M"
start_date = "198801"
end_date = "202502"
code2 = "*AA"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}"

response = requests.get(url)
data = response.json()

df1 = pd.DataFrame(data['StatisticSearch']['row'])
df_export_value_index = df1[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_export_value_index.rename(columns={'DATA_VALUE':'수출금액지수'},inplace=True)
df_export_value_index
# Out:
# <ipython-input-1-08aabe3de808>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export_value_index.rename(columns={'DATA_VALUE':'수출금액지수'},inplace=True)
#        TIME  수출금액지수
# 0    198801    9.54
# 1    198802    9.94
# 2    198803    11.6
# 3    198804   11.13
# 4    198805   11.27
# ..      ...     ...
# 441  202410   133.9
# 442  202411     131
# 443  202412   141.3
# 444  202501   112.8
# 445  202502  124.11
#
# [446 rows x 2 columns]

# %% [markdown]
# 수입금액지수

# %%
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "403Y003"
start = "1"
end = "100000"
period = "M"
start_date = "198801"
end_date = "202502"
code2 = "*AA"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}"

response = requests.get(url)
data = response.json()

df2 = pd.DataFrame(data['StatisticSearch']['row'])
df_import_value_index = df2[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_import_value_index.rename(columns={'DATA_VALUE':'수입금액지수'},inplace=True)
df_import_value_index
# Out:
# <ipython-input-2-6ebd1a901497>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_import_value_index.rename(columns={'DATA_VALUE':'수입금액지수'},inplace=True)
#        TIME  수입금액지수
# 0    198801    9.11
# 1    198802     9.3
# 2    198803   10.48
# 3    198804   10.79
# 4    198805   10.64
# ..      ...     ...
# 441  202410  140.02
# 442  202411  129.76
# 443  202412  138.58
# 444  202501  130.61
# 445  202502  123.65
#
# [446 rows x 2 columns]

# %% [markdown]
# 수출물가지수

# %%
#원화기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "402Y014"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "W"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df3 = pd.DataFrame(data['StatisticSearch']['row'])
df_export_price_index_w = df3[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_export_price_index_w.rename(columns={'DATA_VALUE':'수출물가지수(원화기준)'},inplace=True)
df_export_price_index_w
# Out:
# <ipython-input-3-8f0381e98b4e>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export_price_index_w.rename(columns={'DATA_VALUE':'수출물가지수(원화기준)'},inplace=True)
#        TIME 수출물가지수(원화기준)
# 0    197101        18.86
# 1    197102        18.95
# 2    197103        19.09
# 3    197104         19.4
# 4    197105         19.5
# ..      ...          ...
# 645  202410       128.54
# 646  202411       130.57
# 647  202412       133.56
# 648  202501       135.31
# 649  202502       134.56
#
# [650 rows x 2 columns]

# %%
#계약통화기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "402Y014"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "C"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df4 = pd.DataFrame(data['StatisticSearch']['row'])
df_export_price_index_c = df4[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_export_price_index_c.rename(columns={'DATA_VALUE':'수출물가지수(계약통화기준)'},inplace=True)
df_export_price_index_c
# Out:
# <ipython-input-4-eaabd428146f>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export_price_index_c.rename(columns={'DATA_VALUE':'수출물가지수(계약통화기준)'},inplace=True)
#        TIME 수출물가지수(계약통화기준)
# 0    197101          71.65
# 1    197102          71.57
# 2    197103          71.77
# 3    197104          72.43
# 4    197105          72.27
# ..      ...            ...
# 645  202410         113.39
# 646  202411         112.84
# 647  202412         112.36
# 648  202501         112.38
# 649  202502         112.36
#
# [650 rows x 2 columns]

# %%
#달러기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "402Y014"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "D"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df5 = pd.DataFrame(data['StatisticSearch']['row'])
df_export_price_index_d = df5[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_export_price_index_d.rename(columns={'DATA_VALUE':'수출물가지수(달러기준)'},inplace=True)
df_export_price_index_d
# Out:
# <ipython-input-5-9ae85ecd4aff>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export_price_index_d.rename(columns={'DATA_VALUE':'수출물가지수(달러기준)'},inplace=True)
#        TIME 수출물가지수(달러기준)
# 0    197101        70.92
# 1    197102        70.86
# 2    197103        71.06
# 3    197104        71.72
# 4    197105        71.55
# ..      ...          ...
# 645  202410       111.36
# 646  202411       110.49
# 647  202412       109.79
# 648  202501       109.59
# 649  202502       109.77
#
# [650 rows x 2 columns]

# %% [markdown]
# 수입물가지수

# %%
#원화기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "401Y015"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "W"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df6 = pd.DataFrame(data['StatisticSearch']['row'])
df_import_price_index_w = df6[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_import_price_index_w.rename(columns={'DATA_VALUE':'수입물가지수(원화기준)'},inplace=True)
df_import_price_index_w
# Out:
# <ipython-input-6-4eb9e163c120>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_import_price_index_w.rename(columns={'DATA_VALUE':'수입물가지수(원화기준)'},inplace=True)
#        TIME 수입물가지수(원화기준)
# 0    197101            6
# 1    197102         6.05
# 2    197103         6.13
# 3    197104         6.17
# 4    197105         6.24
# ..      ...          ...
# 645  202410       137.55
# 646  202411        138.8
# 647  202412       141.98
# 648  202501       145.08
# 649  202502       143.95
#
# [650 rows x 2 columns]

# %%
#계약통화기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "401Y015"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "C"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df7 = pd.DataFrame(data['StatisticSearch']['row'])
df_import_price_index_c = df7[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_import_price_index_c.rename(columns={'DATA_VALUE':'수입물가지수(계약통화기준)'},inplace=True)
df_import_price_index_c
# Out:
# <ipython-input-7-8d07d197d017>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_import_price_index_c.rename(columns={'DATA_VALUE':'수입물가지수(계약통화기준)'},inplace=True)
#        TIME 수입물가지수(계약통화기준)
# 0    197101          25.09
# 1    197102          25.14
# 2    197103          25.38
# 3    197104          25.36
# 4    197105          25.44
# ..      ...            ...
# 645  202410         122.24
# 646  202411         120.97
# 647  202412         120.56
# 648  202501         121.75
# 649  202502         121.32
#
# [650 rows x 2 columns]

# %%
#달러기준
import requests
import pandas as pd
import json

# API 파라미터 설정
service_key = "3IY8CKY4F8FZ3ON5PFY2"
stat_code = "401Y015"
start = "1"
end = "100000"
period = "M"
start_date = "197101"
end_date = "202502"
code2 = "*AA"
code3 = "D"

url = f"https://ecos.bok.or.kr/api/StatisticSearch/{service_key}/json/kr/{start}/{end}/{stat_code}/{period}/{start_date}/{end_date}/{code2}/{code3}"

response = requests.get(url)
data = response.json()

df8 = pd.DataFrame(data['StatisticSearch']['row'])
df_import_price_index_d = df8[['TIME', 'DATA_VALUE']] # 기준 2020년 100
df_import_price_index_d.rename(columns={'DATA_VALUE':'수입물가지수(달러기준)'},inplace=True)
df_import_price_index_d
# Out:
# <ipython-input-8-5473a3894d75>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_import_price_index_d.rename(columns={'DATA_VALUE':'수입물가지수(달러기준)'},inplace=True)
#        TIME 수입물가지수(달러기준)
# 0    197101        23.35
# 1    197102        23.39
# 2    197103        23.61
# 3    197104         23.6
# 4    197105        23.68
# ..      ...          ...
# 645  202410       119.19
# 646  202411       117.48
# 647  202412       116.73
# 648  202501       117.52
# 649  202502       117.44
#
# [650 rows x 2 columns]

# %%
from functools import reduce

# 병합 대상 DataFrame 리스트
dfs = [
    df_export_value_index,
    df_import_value_index,
    df_export_price_index_w,
    df_export_price_index_c,
    df_export_price_index_d,
    df_import_price_index_w,
    df_import_price_index_c,
    df_import_price_index_d
]

# TIME 컬럼 기준으로 순차 병합
merged_df = reduce(lambda left, right: pd.merge(left, right, on='TIME', how='outer'), dfs)

# 결과 확인
merged_df
# Out:
#        TIME  수출금액지수  수입금액지수 수출물가지수(원화기준) 수출물가지수(계약통화기준) 수출물가지수(달러기준)  \
# 0    197101     NaN     NaN        18.86          71.65        70.92
# 1    197102     NaN     NaN        18.95          71.57        70.86
# 2    197103     NaN     NaN        19.09          71.77        71.06
# 3    197104     NaN     NaN         19.4          72.43        71.72
# 4    197105     NaN     NaN         19.5          72.27        71.55
# ..      ...     ...     ...          ...            ...          ...
# 645  202410   133.9  140.02       128.54         113.39       111.36
# 646  202411     131  129.76       130.57         112.84       110.49
# 647  202412   141.3  138.58       133.56         112.36       109.79
# 648  202501   112.8  130.61       135.31         112.38       109.59
# 649  202502  124.11  123.65       134.56         112.36       109.77
#
#     수입물가지수(원화기준) 수입물가지수(계약통화기준) 수입물가지수(달러기준)
# 0              6          25.09        23.35
# 1           6.05          25.14        23.39
# ...

# %%
import pandas as pd
from datetime import timedelta

# 예시: merged_df의 TIME이 'YYYYMM' 형식이라고 가정
# 먼저 TIME을 날짜형으로 변환
merged_df['TIME'] = pd.to_datetime(merged_df['TIME'], format='%Y%m')

# 월별 데이터를 일별로 확장
daily_rows = []

for _, row in merged_df.iterrows():
    start_date = row['TIME']
    # 해당 월의 마지막 날짜 구하기
    next_month = (start_date + pd.offsets.MonthBegin(1))
    end_date = next_month - timedelta(days=1)

    # 일별 날짜 생성
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        new_row = row.copy()
        new_row['DATE'] = date
        daily_rows.append(new_row)

# 새 데이터프레임 생성
daily_df = pd.DataFrame(daily_rows)

daily_df = daily_df.reset_index(drop=True)

# 결과 확인
daily_df
# Out:
#             TIME  수출금액지수  수입금액지수 수출물가지수(원화기준) 수출물가지수(계약통화기준) 수출물가지수(달러기준)  \
# 0     1971-01-01     NaN     NaN        18.86          71.65        70.92
# 1     1971-01-01     NaN     NaN        18.86          71.65        70.92
# 2     1971-01-01     NaN     NaN        18.86          71.65        70.92
# 3     1971-01-01     NaN     NaN        18.86          71.65        70.92
# 4     1971-01-01     NaN     NaN        18.86          71.65        70.92
# ...          ...     ...     ...          ...            ...          ...
# 19778 2025-02-01  124.11  123.65       134.56         112.36       109.77
# 19779 2025-02-01  124.11  123.65       134.56         112.36       109.77
# 19780 2025-02-01  124.11  123.65       134.56         112.36       109.77
# 19781 2025-02-01  124.11  123.65       134.56         112.36       109.77
# 19782 2025-02-01  124.11  123.65       134.56         112.36       109.77
#
#       수입물가지수(원화기준) 수입물가지수(계약통화기준) 수입물가지수(달러기준)       DATE
# ...

# %%
daily_df.drop(columns=['TIME'],inplace=True)
daily_df
# Out:
#        수출금액지수  수입금액지수 수출물가지수(원화기준) 수출물가지수(계약통화기준) 수출물가지수(달러기준) 수입물가지수(원화기준)  \
# 0         NaN     NaN        18.86          71.65        70.92            6
# 1         NaN     NaN        18.86          71.65        70.92            6
# 2         NaN     NaN        18.86          71.65        70.92            6
# 3         NaN     NaN        18.86          71.65        70.92            6
# 4         NaN     NaN        18.86          71.65        70.92            6
# ...       ...     ...          ...            ...          ...          ...
# 19778  124.11  123.65       134.56         112.36       109.77       143.95
# 19779  124.11  123.65       134.56         112.36       109.77       143.95
# 19780  124.11  123.65       134.56         112.36       109.77       143.95
# 19781  124.11  123.65       134.56         112.36       109.77       143.95
# 19782  124.11  123.65       134.56         112.36       109.77       143.95
#
#       수입물가지수(계약통화기준) 수입물가지수(달러기준)       DATE
# ...

# %%
# CSV 파일로 저장
daily_df.to_csv('ex_import.csv', index=False, encoding='utf-8-sig')
